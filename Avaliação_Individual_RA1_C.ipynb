# %% [markdown]
# <a href="https://colab.research.google.com/github/uPistola/Char_Reader-and-File_Transform/blob/main/Avalia%C3%A7%C3%A3o_Individual_RA1_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instruções:
# Para a realização desta tarefa você precisa fazer uma cópia deste carderno de questões para a sua conta. Você responderá a questão colando no AVA o link para a sua cópia contendo as suas respostas.
#
# Todas as questões precisam ser resolvidas algébrica e computacionalmente. Usando todos os recursos computacionais disponíveis na internet. Mas, você não pode consultar outros seres humanos.
#
# **Não se equeça de preencher seu nome nesta célula:**
# # Nome

# %% [markdown]
# # Questão 1:
# O tempo necessário para baixar um arquivo pode ser calculado usando logaritmos. Se a taxa de transferência de dados é de 10 Mbps e o tamanho do arquivo é de 2 GB, quanto tempo levará para baixar o arquivo? Use a fórmula:
#
# $$
# T = \frac{8 \cdot S}{R \cdot 10^6}
# $$
#
# onde $T$ é o tempo em segundos, $S$ é o tamanho do arquivo em GB e $R$ é a taxa de transferência em Mbps. Para calcular o tempo em minutos, faça $T / 60$. Não se esqueça de traçar um gráfico mostrando o o tempo de downloads para arquivos que estão entre 1 e 20 GB.

# %%
import matplotlib.pyplot as plt
import numpy as np

def t(mbps, tamanho):
    return ((8 * tamanho) / (mbps * pow(10,6)))

tamanho = np.arange(1, 20)
tempo = [(t(10, i * 1000000000) / 60) for i in tamanho]

plt.plot(tamanho,tempo)
plt.title("Tempo sobre Tamanho")
plt.xlabel("Tamanho Arquivo(Gb)")
plt.ylabel("Tempo (m)")
plt.show()

# %% [markdown]
# # Questão 2
# Usando, a seu critério, as bibliotecas do Python, crie um gráfico para cada uma das funções a seguir. No label do gráfico deverá estar a função impressa com qualidade matemática (latex) e uma label dizendo se a função é crescente ou decrescente.
#
# 1. $e^x - 4x^2 = 0$
#
# 2. $\log_3(x^2 + 1) - \log_3(x) = 2$

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.exp(x) - 4*x**2

# create a range of x values to plot
x = np.linspace(-3, 3, 1000)

# calculate y values for each x value
y = f(x)

# plot the graph
plt.plot(x, y)
plt.xlabel('$e^x - 4x^2 = 0$')
plt.ylabel('Função Decrescente')
plt.title('Grafico de $e^x - 4x^2 = 0$, Range = -3 / 3')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return np.exp(x) - 4*x**2

# create a range of x values to plot
x = np.linspace(-18, 18, 1000)

# calculate y values for each x value
y = f(x)

# plot the graph
plt.plot(x, y)
plt.xlabel('$e^x - 4x^2 = 0$')
plt.ylabel('Função Decrescente')
plt.title('Grafico de $e^x - 4x^2 = 0$, Range = -18 / 18')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.1, 20, 1000)
y = np.log10((x**2 + 1)/x)

plt.plot(x, y)
plt.plot([0,9], [2,2], 'r--')

# plot the graph
plt.plot(x, y)
plt.xlabel('$\log_3(x^2 + 1) - \log_3(x) = 2$')
plt.ylabel('Função Crescente')
plt.title('Grafico de $\log_3(x^2 + 1) - \log_3(x) = 2$, Range = 0.1 / 20')
plt.grid()
plt.show()

# %% [markdown]
# # Questão 3
# Usando o Sympy, ou qualquer outro recurso disponível na internet, escreva, com qualidade matemática o passo-a-passo algébrico que leva a determinação dos seguintes limites. Ao final, para cada uma das equações você deverá traçar um gráfico da função.
#
# 1. $\lim_{x \to 0} \frac{\sin(2x)}{x}$
#
# 2. $\lim_{x \to \infty} \frac{e^x}{x^3}$

# %% [markdown]
# $\lim _{x\to \:0}\left(\frac{\sin \left(2x\right)}{x}\right)$
#
# $\lim _{x\to \:0}\left(\frac{\cos \left(2x\right)\cdot \:2}{1}\right)$
#
# $\frac{\cos \left(2\cdot \:0\right)\cdot \:2}{1} : 2$

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import *

x = symbols('x')
f = sin(2*x)/x

fig, ax = plt.subplots()
xs = np.linspace(-5, 5, 500)
ys = [f.subs(x, i) for i in xs]
ax.plot(xs, ys, label='f(x)')

plt.axhline(y=2, color='r', linestyle='--', label='limite')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import *

x = symbols('x')
f = exp(x)/x**3

fig, ax = plt.subplots()
xs = np.linspace(-5, 5, 50)
ys = [f.subs(x, i) for i in xs]
ax.plot(xs, ys, label='f(x)')

plt.axvline(x=0, color='gray')
plt.axhline(y=0, color='gray')

plt.legend()
plt.show()
